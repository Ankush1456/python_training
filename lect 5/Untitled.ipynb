# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import PIL

# %%
cb_pil= PIL.Image.open("cb_tshirt_logo.png")

# %%
cb_np = np.array(cb_pil)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
panda_pil = PIL.Image.open("pand.jpg")

# %%
np_panda =np.array(panda_pil)

# %%
np_panda.shape
# Out:
# (362, 474, 3)

# %%
panda_np = np.array(panda_pil)

# %%
panda_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x362 at 0x227284D2108>

# %%
cut = panda_np[:cb_np.shape[0],-cb_np.shape[1]:]

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if cb_np[row,col,3]>100:
            cut[row,col]= cb_np[row,col,:3]

# %%
plt.imshow(panda_np)
