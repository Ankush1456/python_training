# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
img = np.zeros((100,100,3), dtype= np.uint8)

# %%
plt.imshow(img)

# %%
img[:30, :, 0] = 255

# %%
plt.imshow(img)

# %%
img[60:,30 :, 1] = 255

# %%
plt.imshow(img)

# %%
import PIL

# %%
pan = PIL.Image.open("C:\\Users\\Ankush sharma\\Desktop\\python Training\\lecture 1\\panda.jpg")

# %%
pan
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x452 at 0x20A430BA4C8>

# %%
type(pan)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
chacha = np.array(pan)

# %%
type(chacha)
# Out:
# numpy.ndarray

# %%
chacha.shape
# Out:
# (452, 678, 3)

# %%
short= chacha[::2,::2].copy()

# %%
plt.imshow(short)

# %%
coverted_array = PIL.Image.fromarray(short)
file = open("pandas.jpg", "wb")

# %%
coverted_array.save(file)
